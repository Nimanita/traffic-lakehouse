# %%
file_list = dbutils.fs.ls("/Volumes/dev_catalog/landing/landing_vol/raw_traffic/")
display(file_list)

# %%
file_list = dbutils.fs.ls("/Volumes/dev_catalog/landing/landing_vol/raw_roads/")
display(file_list)
